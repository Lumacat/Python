# %%
import random

who_starts = input('welcome to pebble game! will you make the first move? y/n ' )
if who_starts == 'y':
    pebble_stack = int(input('type number of pebbles you want '))
    s1 = pebble_stack
    s2 = pebble_stack
    print('here are the two pebble stacks')
    print("O" * s1 + "  " + "O" * s2)

    print('press enter to start game and make your move')
    input()

    while s1 > 0 or s2 > 0:
        if s1%2 == 0 and s2%2 == 0:
            print('YOU LOST')
            break
        if s1%2 == 0:
            pass
        else:
            s1 -= 1
        if s2%2 == 0:
            pass
        else:
            s2 -= 1
        if s1 == 0 and s2 == 0:
            print('YOU WON')
            break
        print("O" * s1 + "  " + "O" * s2)
        print('press enter to view your opponent view ')
        input()
        if s1 > 0:
            if s2 == 0:
                s1 -= 1
            else:
                rand_sub = random.randint(0, 1)
                s1 = s1 - rand_sub
        else:
            pass
        if s2 > 0:
            if s1 == 0:
                s2 -= 1
            elif rand_sub == 0:
                s2 -= 1
            else:
                s2 = s2 - random.randint(0, 1)
        else:
            pass
        print("O" * s1 + "  " + "O" * s2)
        print('press enter to make your move ')
        input()
        if s1 == 0 and s2 == 0:
            print('YOU WON')
        else:
            continue
elif who_starts == 'n':
    pebble_stack = int(input('type number of pebbles you want '))
    s1 = pebble_stack
    s2 = pebble_stack
    print('here are the two pebble stacks')
    print("O" * s1 + "  " + "O" * s2)

    print('press enter to start game and view opponent move')
    input()

    while s1 > 0 or s2 > 0:
        if s1 > 0:
            if s2 == 0:
                s1 -= 1
            else:
                rand_sub = random.randint(0, 1)
                s1 = s1 - rand_sub
        else:
            pass
        if s2 > 0:
            if s1 == 0:
                s2 -= 1
            elif rand_sub == 0:
                s2 -= 1
            else:
                s2 = s2 - random.randint(0, 1)
        else:
            pass
        print("O" * s1 + "  " + "O" * s2)
        print('press enter to play your move ')
        input()
        if s1%2 == 0 and s2%2 == 0:
            print('YOU LOST')
            break
        if s1%2 == 0:
            pass
        else:
            s1 -= 1
        if s2%2 == 0:
            pass
        else:
            s2 -= 1
        print("O" * s1 + "  " + "O" * s2)
        print('press enter to view opponent move ')
        input()
        if s1 == 0 and s2 == 0:
            print('YOU WON')
        else:
            continue
else:
    print('only y or n are acceptable answsers')
